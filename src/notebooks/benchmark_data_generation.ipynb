# %%
# %load_ext autoreload
# %autoreload 2

# %%
import uuid
import time
from typing import List

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.utils.validation import check_is_fitted
from statsmodels.tsa.stattools import adfuller
from IPython.display import Code, display
import inspect

import avh.utility_functions as utils
from avh.data_issues import (
    IssueTransfomer,
    NumericIssueTransformer,
    CategoricalIssueTransformer,
    IncreasedNulls,
    SchemaChange,
    DistributionChange,
    UnitChange,
    CasingChange,
    DQIssueDatasetGenerator,
    VolumeChangeUpsample,
    VolumeChangeDownsample,
    NumericPerturbation,
    DistributionChangeV2,
    DistributionChangeV3,
)

from avh.data_generation import (
    DataColumn,
    NumericColumn,
    CategoricalColumn,
    NormalNumericColumn,
    UniformNumericColumn,
    BetaNumericColumn,
    StaticCategoricalColumn,
    RandomCategoricalColumn,
    DataGenerationPipeline,
)

from avh.metrics import (
    Metric,
    SingleDistributionMetric,
    TwoDistributionMetric,
    RowCount,
    DistinctCount,
    DistinctRatio,
    CompleteRatio,
    Mean,
    Median,
    Range,
    Min,
    Max,
    Sum,
    MeanDigitLength,
    MeanPunctuationLength,
    MeanStringLength,
    EMD,
    KsDist,
    CohenD,
    KlDivergence,
    JsDivergence,
)

from avh.constraints import (
    Constraint,
    ConstantConstraint,
    ChebyshevConstraint,
    CantelliConstraint,
    CLTConstraint,
    ConjuctivDQProgram,
)

from avh.auto_validate_by_history import AVH

# %%
import jupyter_black

jupyter_black.load()
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
rng = np.random.default_rng(42)

# %%
pipeline = DataGenerationPipeline(
    columns=[
        NormalNumericColumn("money", 300, 10),
        NormalNumericColumn("height", 18, 2),
        UniformNumericColumn("houses", 30, 50, dtype=np.int32),
        RandomCategoricalColumn("pets", ["dog", "cat", "snail"]),
        # RandomCategoricalColumn("pets2", ["dog", "cat", "snail"]),
        # RandomCategoricalColumn("text"),
    ],
    issues=[
        ("money", [IncreasedNulls(p=0.1)]),
        # ("height", [IncreasedNulls(p=0.99)]),
        # ("pets", [IncreasedNulls(p=0.5)]),
    ],
    random_state=rng,
)

# %%
# Defining M space
M = [
    RowCount,
    DistinctRatio,
    DistinctCount,
    CompleteRatio,
    Min,
    Max,
    Mean,
    Median,
    Sum,
    Range,
    EMD,
    JsDivergence,
    KlDivergence,
    KsDist,
    CohenD,
]

# Defining available constraint estimators
# Note: Order not important as Q space will be constructed
#     from cartesian product of E & M
E = [
    CLTConstraint,
    ChebyshevConstraint,
    CantelliConstraint,
]

H = [pipeline.generate_normal(100000, 10) for i in range(31)]

# %%
issue = DistributionChange(p=0.5, take_last=True, random_state=42)
issuev2 = DistributionChangeV2(p=0.5, take_last=True, random_state=42)
issuev3 = DistributionChangeV3(p=0.5, take_last=True, random_state=42)

# %%
# %%time
v1 = issue.fit_transform(H_FULL[-1])
# Out:
# CPU times: user 9.68 s, sys: 118 ms, total: 9.8 s
# Wall time: 9.85 s

# %%
# %%time
# v2 = issuev2.fit_transform(H[-1])

# %%
# %%time
v3 = issuev3.fit_transform(H_FULL[-1])
# Out:
# CPU times: user 15.6 s, sys: 537 ms, total: 16.2 s
# Wall time: 2.46 s

# %%
v1
# Out:
#           height  houses   pets       money
# 0      17.990353      39    dog  300.007935
# 1      17.990496      39    dog  300.007965
# 2      17.990515      39    dog  300.008850
# 3      17.990595      39    dog  300.009308
# 4      17.990631      39    dog  300.009430
# ...          ...     ...    ...         ...
# 99994  26.078815      49  snail  338.093079
# 99995  26.210125      49  snail  342.582733
# 99996  26.423977      49  snail  342.686188
# 99997  26.635475      49  snail  342.765228
# 99998  17.990353      39    dog  343.907776
#
# [99999 rows x 4 columns]

# %%
v3
# Out:
#           height  houses   pets       money
# 0      17.990353      39    dog  300.007935
# 1      17.990496      39    dog  300.007965
# 2      17.990515      39    dog  300.008850
# 3      17.990595      39    dog  300.009308
# 4      17.990631      39    dog  300.009430
# ...          ...     ...    ...         ...
# 99994  26.078815      49  snail  338.093079
# 99995  26.210125      49  snail  342.582733
# 99996  26.423977      49  snail  342.686188
# 99997  26.635475      49  snail  342.765228
# 99998  17.990353      39    dog  343.907776
#
# [99999 rows x 4 columns]

# %%
v1.equals(v3)
# Out:
# True

# %%
v2
# Out:
#          numeric_0     numeric_1    numeric_2  numeric_3     numeric_4  \
# 0         0.053327 -84432.109375    55.313244       8736 -67792.000000
# 1         0.054230 -84418.062500    89.205055       9017 -67792.000000
# 2         0.116228 -84132.828125    97.113022       9713 -67792.000000
# 3         0.138798 -83650.843750   127.328445      11962 -67792.000000
# 4         0.283126 -83237.507812   133.694061      13023 -67792.000000
# ...            ...           ...          ...        ...           ...
# 107247  503.928070 -65310.804688  4404.182129      40752 -67632.390625
# 107248  504.010620 -65310.761719  4404.510254      40753 -67632.367188
# 107249  504.045380 -65310.519531  4404.707520      40753 -67632.343750
# 107250    0.053327 -84432.109375    55.313244       8736 -67792.000000
# 107251    0.054230 -84418.062500    89.205055       9017 -67792.000000
#
#         numeric_5     numeric_6    numeric_7     numeric_8  numeric_9  ...  \
# 0           11455 -79503.015625  2599.174072   9059.712891      25761  ...
# 1           12130 -79462.835938  2625.439697  12931.257812      25761  ...
# 2           14428 -79433.789062  2633.321777  14370.169922      25761  ...
# 3           15439 -79402.968750  2682.683594  14685.614258      25761  ...
# 4           16356 -79302.656250  2732.687988  15610.158203      25761  ...
# ...           ...           ...          ...           ...        ...  ...
# 107247      45462 -69736.117188  9442.489258  54259.707031      26680  ...
# 107248      45462 -69735.828125  9442.504883  54260.531250      26681  ...
# 107249      45464 -69735.617188  9442.945312  54261.417969      26681  ...
# 107250      11455 -79503.015625  2599.174072   9059.712891      25761  ...
# 107251      12130 -79462.835938  2625.439697  12931.257812      25761  ...
#
#         numeric_990   numeric_991  numeric_992  numeric_993  numeric_994  \
# 0              4266 -34221.335938       -43313       -17846            0
# 1              7761 -33815.214844       -43313       -17746            0
# 2              8842 -33648.117188       -43312       -17664            0
# 3              8973 -33642.355469       -43312       -17315            0
# 4              9353 -33637.082031       -43312       -17285            0
# ...             ...           ...          ...          ...          ...
# 107247        35895 -27781.166016       -42286       -12702          279
# 107248        35896 -27780.759766       -42286       -12702          279
# 107249        35896 -27780.707031       -42286       -12701          280
# 107250         4266 -34221.335938       -43313       -17846            0
# 107251         7761 -33815.214844       -43313       -17746            0
#
#         numeric_995   numeric_996  numeric_997   numeric_998  numeric_999
# 0             -9459 -73845.523438     0.359601    381.975586            0
# 1             -9099 -73806.671875     0.546967    491.534515            0
# 2             -9097 -73606.750000     0.553102    786.924255            0
# 3             -8991 -73501.164062     0.812114    830.549255            0
# 4             -8984 -73442.898438     0.820959    901.833069            0
# ...             ...           ...          ...           ...          ...
# 107247        -5393 -54774.566406   170.221481  11350.974609           19
# 107248        -5393 -54773.859375   170.234299  11351.440430           19
# 107249        -5393 -54773.687500   170.254623  11351.444336           19
# 107250        -9459 -73845.523438     0.359601    381.975586            0
# 107251        -9099 -73806.671875     0.546967    491.534515            0
#
# [107252 rows x 1000 columns]

# %%
v2
# Out:
#           height  houses pets       money
# 0       9.667356      30  cat  260.409363
# 1       9.814260      30  cat  260.885437
# 2       9.963401      30  cat  261.014618
# 3      10.126824      30  cat  261.351440
# 4      10.140945      30  cat  262.117249
# ...          ...     ...  ...         ...
# 99994  10.140945      30  cat  287.166504
# 99995  10.378928      30  cat  287.167297
# 99996  10.407301      30  cat  287.167480
# 99997  10.485166      30  cat  287.167999
# 99998  10.515101      30  cat  287.168121
#
# [99999 rows x 4 columns]

# %%
avh = AVH(M, E, random_state=42, verbose=6, columns=["money"])

# %%
PS = avh.generate(H, fpr_target=0.05)
# Out:
# creating D(C)...: 23it [00:00, 50.89it/s]
# Generating P(S for columns...:   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-05-01 13:59:32|DEBUG|utility_functions.wrapper: avh.auto_validate_by_history._generate_constraint_space Took 668.4990 ms to execute.
# Generating P(S for columns...: 100%|██████████| 1/1 [00:05<00:00,  5.41s/it]
# 2024-05-01 13:59:37|DEBUG|utility_functions.wrapper: avh.auto_validate_by_history._precalculate_constraint_recalls_fast Took 4725.4651 ms to execute.
# 2024-05-01 13:59:37|DEBUG|utility_functions.wrapper: avh.auto_validate_by_history._find_optimal_singleton_conjuctive_dq_program Took 0.1028 ms to execute.
# 2024-05-01 13:59:37|DEBUG|utility_functions.wrapper: avh.auto_validate_by_history._find_optimal_conjunctive_dq_program Took 0.3271 ms to execute.
# 2024-05-01 13:59:37|DEBUG|utility_functions.wrapper: avh.auto_validate_by_history._generate_conjuctive_dq_program Took 4730.6402 ms to execute.
# 2024-05-01 13:59:37|DEBUG|utility_functions.wrapper: avh.auto_validate_by_history.generate Took 5881.4399 ms to execute.

# %%
PS
# Out:
# {'money': ChebyshevConstraint(2686488.8684 <= Sum <= 2714968.6316, FPR = 0.0400), FPR = 0.040000}

# %% [markdown]
# ### Synthetic benchmark data generation

# %% [markdown]
# **Benchmark setup**
# columns:
# - Numeric:
#     - count: 1000
#     - dtypes:
#         - int: 30%
#         - float: 70%
#     - distributions:
#         - uniform: 10%
#         - normal: 20%
#         - beta: 70%
# - Categorical:
#     - count: 1000

# %%
rng = np.random.default_rng(42)
n = 1000

numeric_columns = []
for i in range(n):

    column_name = f"numeric_{i}"
    dtype = rng.choice([np.int32, np.float32], p=[0.3, 0.7])
    distribution = rng.choice(["uniform", "normal", "beta"], p=[0.1, 0.1, 0.8])

    scale = rng.integers(1, 100000)
    sign = rng.choice([-1, 1], p=[0.2, 0.8])

    if distribution == "uniform":
        low = rng.uniform(0, scale)
        high = rng.uniform(low, scale)

        if sign == -1:
            low, high = high * sign, low * sign

        column = UniformNumericColumn(column_name, low, high, dtype=dtype)

    elif distribution == "normal":
        mean = rng.uniform(0, scale) * sign
        std = rng.uniform(0, 10)
        column = NormalNumericColumn(column_name, mean, std, dtype=dtype)

    elif distribution == "beta":
        alfa = rng.uniform(0.1, 10)
        beta = rng.uniform(0.1, 10)
        column = BetaNumericColumn(
            column_name, alfa, beta, scale=scale * sign, dtype=dtype
        )

    numeric_columns.append(column)

pipeline = DataGenerationPipeline(numeric_columns, random_state=rng)

# %%
_ = pipeline.generate(10)
pipeline.generate(10)
# Out:
#       numeric_0     numeric_1     numeric_2  numeric_3     numeric_4  \
# 0   5821.104980 -34834.832031  11238.599609      60716 -66111.226562
# 1  10925.531250 -26888.644531   7864.008301      54449 -67443.421875
# 2    501.136169 -37594.253906   3560.182373      63364 -66828.265625
# 3   8450.057617 -43200.699219  21597.923828      50026 -35321.585938
# 4    853.856262 -68572.703125  14830.930664      61871 -67020.437500
# 5   5146.479492 -56280.953125   6069.199219      54402 -52296.609375
# 6     78.213112 -23492.179688   2075.531738      34764 -55568.453125
# 7   2068.486816 -62414.558594   9188.073242      63151 -67206.203125
# 8   2648.368652 -59181.843750  22179.609375      49566 -55144.070312
# 9    228.171494 -29470.943359   9205.548828      68273 -64909.343750
#
#    numeric_5     numeric_6     numeric_7     numeric_8  numeric_9  ...  \
# 0      63082 -51763.378906  15023.037109  81354.015625      31916  ...
# 1      64605 -35486.953125  10741.845703  64389.609375      29698  ...
# 2      71020 -51227.363281  10221.790039  82744.335938      31576  ...
# 3      58457 -57433.160156  14897.063477  72058.531250      26262  ...
# 4      55112 -29222.072266  13150.475586  74611.960938      32657  ...
# 5      68768 -34627.914062  14542.632812  72402.140625      26402  ...
# 6      55883 -52167.539062   9609.795898  75772.273438      28715  ...
# 7      68311 -39544.320312   8298.933594  73562.179688      27038  ...
# 8      46833 -52097.671875  15849.641602  66682.640625      32410  ...
# 9      70608 -45762.242188  16670.693359  71053.734375      31205  ...
#
#    numeric_990   numeric_991  numeric_992  numeric_993  numeric_994  \
# 0        40273 -18550.923828       -35820       -12002         4568
# 1        39738 -22038.558594       -39154       -13365           33
# 2        39960 -21410.837891       -29715       -10334        19782
# 3        31435 -17814.777344       -42209       -10778         7125
# 4        40299 -27168.732422       -41292       -11566         9054
# 5        40125 -26632.451172       -33060        -8514         4918
# 6        40273 -17016.589844       -41198        -7225         1124
# 7        39464 -21363.919922       -42758       -10456         8527
# 8        38680 -27883.966797       -35883        -8601         1364
# 9        30016 -17459.476562       -36026       -10307          130
#
#    numeric_995   numeric_996  numeric_997   numeric_998  numeric_999
# 0        -2344 -16475.402344   925.599182  30427.248047         2100
# 1        -3469 -12637.672852   986.680237  14986.859375        24766
# 2        -2780 -46713.929688  1121.689941  24671.345703         6055
# 3         -784 -33630.265625   317.320984   4732.359863           92
# 4        -1135 -49678.265625   894.154236   8903.215820         1332
# 5        -5780 -38391.890625   241.083893  14546.629883          895
# 6        -1048 -42372.964844   559.309387  38492.242188         2613
# 7        -4460 -52713.937500   347.820770  24417.640625        18088
# 8         -227 -58724.406250  1006.673279   8738.956055         7082
# 9        -2129 -56958.410156  1366.932861  39745.515625        10437
#
# [10 rows x 1000 columns]

# %%
H_FULL = [pipeline.generate_normal(100000, 5000) for i in range(31)]

# %%
# Defining M space
M = [
    RowCount,
    DistinctRatio,
    DistinctCount,
    CompleteRatio,
    Min,
    Max,
    Mean,
    Median,
    Sum,
    Range,
]

# Defining available constraint estimators
# Note: Order not important as Q space will be constructed
#     from cartesian product of E & M
E = [CLTConstraint, ChebyshevConstraint]

avh = AVH(M, E, random_state=42)

# %%
PS = avh.generate(H, fpr_target=0.01)
# Out:
# creating D(C)...: 23it [51:58, 135.60s/it]
# Generating P(S for columns...:   7%|▋         | 72/1000 [01:16<16:32,  1.07s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 PS = avh.generate(H, fpr_target=0.01)
#
# File ~/vinted/Auto-Validate-By-History-Clone/src/avh/utility_functions.py:15, in debug_timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      12 local_logger = logging.getLogger(local_logger_name)
#      14 start_time = time.time()
# ---> 15 result = function(*args, **kwargs)
#      16 end_time = time.time()
#      17 elapsed_time_ms = (end_time - start_time) * 1000
#
# File ~/vinted/Auto-Validate-By-History-Clone/src/avh/auto_validate_by_history.py:99, in AVH.generate(self, history, fpr_target)
#      96 columns = self.columns if self.columns else list(history[0].columns)
#      98 for column in tqdm(columns, "Generating P(S for columns...", disable=not self.verbose):
# ---> 99     Q = self._generate_constraint_space(
#     100         [run[column] for run in history[:-1]]
#     101     )
#     103     PS[column] = self._generate_conjuctive_dq_program(
#     104         Q, DC[column], fpr_target
#     105     )
#     107 return PS
#
# File ~/vinted/Auto-Validate-By-History-Clone/src/avh/utility_functions.py:15, in debug_timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      12 local_logger = logging.getLogger(local_logger_name)
#      14 start_time = time.time()
# ---> 15 result = function(*args, **kwargs)
#      16 end_time = time.time()
#      17 elapsed_time_ms = (end_time - start_time) * 1000
#
# File ~/vinted/Auto-Validate-By-History-Clone/src/avh/auto_validate_by_history.py:248, in AVH._generate_constraint_space(self, history)
#     245 if not metric.is_column_compatable(history[0].dtype):
#     246     continue
# --> 248 metric_history = metric.calculate(history)
#     249 metric_history_std = np.nanstd(metric_history)
#     250 # preprocessed_metric_history = None
#     251
#     252 # TODO: put this into another function
#    (...)
#     262 #         preprocessing_func(metric_history), lag
#     263 #     )
#
# File ~/vinted/Auto-Validate-By-History-Clone/src/avh/metrics.py:25, in Metric.calculate(self, data)
#      21 """
#      22 Method for calculating the target metric from given data
#      23 """
#      24 if isinstance(data, list):
# ---> 25     return list(map(self._calculate, data))
#      26 return self._calculate(data)
#
# File ~/vinted/Auto-Validate-By-History-Clone/src/avh/metrics.py:63, in DistinctRatio._calculate(self, column)
#      61 @classmethod
#      62 def _calculate(self, column: pd.Series) -> float:
# ---> 63     return column.nunique(dropna=False) / len(column)
#
# File ~/vinted/Auto-Validate-By-History-Clone/.venv/lib/python3.11/site-packages/pandas/core/base.py:1063, in IndexOpsMixin.nunique(self, dropna)
#    1028 @final
#    1029 def nunique(self, dropna: bool = True) -> int:
#    1030     """
#    1031     Return number of unique elements in the object.
#    1032
#    (...)
#    1061     4
#    1062     """
# -> 1063     uniqs = self.unique()
#    1064     if dropna:
#    1065         uniqs = remove_na_arraylike(uniqs)
#
# File ~/vinted/Auto-Validate-By-History-Clone/.venv/lib/python3.11/site-packages/pandas/core/series.py:2407, in Series.unique(self)
#    2344 def unique(self) -> ArrayLike:  # pylint: disable=useless-parent-delegation
#    2345     """
#    2346     Return unique values of Series object.
#    2347
#    (...)
#    2405     Categories (3, object): ['a' < 'b' < 'c']
#    2406     """
# -> 2407     return super().unique()
#
# File ~/vinted/Auto-Validate-By-History-Clone/.venv/lib/python3.11/site-packages/pandas/core/base.py:1025, in IndexOpsMixin.unique(self)
#    1023     result = values.unique()
#    1024 else:
# -> 1025     result = algorithms.unique1d(values)
#    1026 return result
#
# File ~/vinted/Auto-Validate-By-History-Clone/.venv/lib/python3.11/site-packages/pandas/core/algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File ~/vinted/Auto-Validate-By-History-Clone/.venv/lib/python3.11/site-packages/pandas/core/algorithms.py:440, in unique_with_mask(values, mask)
#     438 table = hashtable(len(values))
#     439 if mask is None:
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# KeyboardInterrupt:

# %%
import time

# %%
def minmax(x):
    time.sleep(1)
    return x.max() - x.min()

# %%
df
# Out:
#         money     height
# 0  306.025787  16.935593
# 1  307.398956  17.327097
# 2  323.848206  18.795792
# 3  293.234497  17.923433
# 4  303.093597  18.694580
# 5  308.189514  16.846575
# 6  298.945801  18.116465
# 7  302.219177  12.018182
# 8  313.597168  18.783092
# 9  294.416443  14.882791

# %%
# %%time
df.apply(minmax, axis=1)
# Out:
# CPU times: user 4.56 ms, sys: 1.32 ms, total: 5.88 ms
# Wall time: 10 s
# 0    289.090210
# 1    290.071869
# 2    305.052429
# 3    275.311066
# 4    284.399017
# 5    291.342926
# 6    280.829346
# 7    290.200989
# 8    294.814087
# 9    279.533661
# dtype: float32

# %%
import dask.dataframe as dd

# %%
ddf = dd.from_pandas(df, npartitions=5)  # Dask DataFrame has 5 partitions

# %%
def minmax2(df):
    return df.apply(minmax, axis=1)

# %%
# %%time
p = ddf.map_partitions(minmax2, meta=(None, "float32"))
p.compute()
# Out:
# CPU times: user 11 ms, sys: 3.08 ms, total: 14.1 ms
# Wall time: 2.02 s
# 0    289.090210
# 1    290.071869
# 2    305.052429
# 3    275.311066
# 4    284.399017
# 5    291.342926
# 6    280.829346
# 7    290.200989
# 8    294.814087
# 9    279.533661
# dtype: float32
